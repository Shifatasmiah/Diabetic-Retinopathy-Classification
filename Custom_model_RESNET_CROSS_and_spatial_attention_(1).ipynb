# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifatasmiah/Diabetic-Retinopathy-Classification/blob/main/Custom_model_RESNET_CROSS_and_spatial_attention_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers import Dense, Flatten,GlobalAveragePooling2D
from keras.models import Sequential
from keras.optimizers import Adam
import pathlib
import pickle
from sklearn.model_selection import KFold

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/Diabetic_retinopathy/retinadataset'
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 399

# %%
img_height, img_width = 224, 224
batch_size = 32
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 399 files belonging to 6 classes.

# %%
class SpatialAttention(tf.keras.layers.Layer):
    def __init__(self):
        super(SpatialAttention, self).__init__()

    def build(self, input_shape):
        self.conv = tf.keras.layers.Conv2D(1, kernel_size=(1,1), strides=(1,1), activation='sigmoid')

    def call(self, inputs):
        # Average and max pooling
        avg_pool = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(inputs, axis=-1, keepdims=True)

        # Concatenate average and max pooling features
        concat = tf.concat([avg_pool, max_pool], axis=-1)

        # Feed concatenated features into a 1x1 convolution layer to compute attention map
        attn = self.conv(concat)

        # Multiply input features with attention map
        output = inputs * attn

        return output

# %%
class_names = dataset.class_names
total_classes = len(class_names)
print(total_classes)
print(class_names)
# Out:
# 6
# ['Hypertensive retinopathy', 'Mild NPDR (1)', 'Moderate NPDR (2)', 'NO_DR 0', 'Proliferative DR 4', 'Severe NPDR 3']

# %%
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

dataset = dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
# convert it to one hot encoded
dataset = dataset.map(lambda x, y: (x, tf.one_hot(y, total_classes)))

# %%
# checkpoint and monitor val_accuracy val_precision val_recall val_f1_score
model_name = 'ResNet152'
checkpoint_filepath = '/content/drive/MyDrive/Diabetic_retinopathy/training_checkpoints' + model_name + '.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose=1,
    period=25
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history_list = []
history_file = "/content/drive/MyDrive/Diabetic_retinopathy/training_history/" + model_name + ".pkl"
if os.path.exists(history_file):
    with open(history_file, "rb") as f:
        history_list = pickle.load(f)
else:
    history_list = []

# %%
data_augmentation = Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.2),
        layers.RandomBrightness(0.2),
        layers.RandomTranslation(0.2, 0.2, fill_mode="nearest"),
        layers.RandomHeight(0.2),
        layers.RandomWidth(0.2),

    ])

# %%
plt.figure(figsize=(10, 10))
for images, _ in dataset.take(2):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[3].numpy().astype("uint8"))
        plt.axis("off")

# %%
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
if os.path.exists(checkpoint_filepath):
    # Load the model from the checkpoint file
    model = tf.keras.saving.load_model(checkpoint_filepath)
    print("Model loaded from checkpoint.")
else:
 pretrained_model = tf.keras.applications.ResNet152(include_top=False,
                                                        input_shape=(img_height, img_width, 3),
                                                        weights='imagenet')

for layer in pretrained_model.layers[:-50]:
    layer.trainable = False

model = Sequential([
    data_augmentation,
    layers.Lambda(tf.keras.applications.efficientnet.preprocess_input),
    pretrained_model,
    SpatialAttention(),  # spatial attention layer
    layers.GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    Dense(total_classes, activation='softmax'),
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 1s 0us/step

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics=[
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tfa.metrics.F1Score(total_classes,name = 'f1_score')
])

# %%
train_images = []
train_labels = []
for images, labels in dataset:
    train_images.append(images.numpy())
    train_labels.append(labels.numpy())

train_images = np.concatenate(train_images)
train_labels = np.concatenate(train_labels)

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=123)

fold = 1
for train_index, val_index in kf.split(train_images):
    print(f"Training fold: {fold}")
    x_train, x_val = train_images[train_index], train_images[val_index]
    y_train, y_val = train_labels[train_index], train_labels[val_index]
    train_fold = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size)
    val_fold = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

    epochs = 100
    history = model.fit(
    train_fold,
    validation_data=val_fold,
    epochs=epochs,
    # callbacks=[model_checkpoint_callback],
    )

    fold += 1

    history_list.append(history.history)

# with open(history_file, "wb") as f:
#     pickle.dump(history_list, f)
# Out:
# Training fold: 1
# Epoch 1/100
# 10/10 [==============================] - 61s 3s/step - loss: 1.6717 - accuracy: 0.3009 - precision: 0.4737 - recall: 0.0282 - f1_score: 0.1882 - val_loss: 1.6782 - val_accuracy: 0.3250 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.1253
# Epoch 2/100
# 10/10 [==============================] - 24s 2s/step - loss: 1.5057 - accuracy: 0.3668 - precision: 0.5714 - recall: 0.0502 - f1_score: 0.2990 - val_loss: 1.8142 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.1037
# Epoch 3/100
# 10/10 [==============================] - 20s 2s/step - loss: 1.2996 - accuracy: 0.4608 - precision: 0.6667 - recall: 0.2006 - f1_score: 0.3360 - val_loss: 1.7857 - val_accuracy: 0.2875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0744
# Epoch 4/100
# 10/10 [==============================] - 14s 1s/step - loss: 1.2478 - accuracy: 0.4953 - precision: 0.6449 - recall: 0.2163 - f1_score: 0.4044 - val_loss: 1.7844 - val_accuracy: 0.2875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0744
# Epoch 5/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.2335 - accuracy: 0.4765 - precision: 0.6638 - recall: 0.2414 - f1_score: 0.4492 - val_loss: 1.7844 - val_accuracy: 0.2875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0744
# Epoch 6/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.1463 - accuracy: 0.5204 - precision: 0.6533 - recall: 0.3072 - f1_score: 0.4905 - val_loss: 1.7838 - val_accuracy: 0.2875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0744
# Epoch 7/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.0660 - accuracy: 0.5455 - precision: 0.6846 - recall: 0.3197 - f1_score: 0.5368 - val_loss: 1.7741 - val_accuracy: 0.2750 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0748
# Epoch 8/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.9957 - accuracy: 0.5611 - precision: 0.6923 - recall: 0.4232 - f1_score: 0.5652 - val_loss: 1.7784 - val_accuracy: 0.2875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.0986
# Epoch 9/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.9922 - accuracy: 0.5674 - precision: 0.6908 - recall: 0.4483 - f1_score: 0.5623 - val_loss: 1.8742 - val_accuracy: 0.3125 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.1482
# Epoch 10/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.9116 - accuracy: 0.6144 - precision: 0.7432 - recall: 0.4263 - f1_score: 0.6154 - val_loss: 1.8476 - val_accuracy: 0.3125 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score: 0.1176
# Epoch 11/100
# 10/10 [==============================] - 12s 1s/step - loss: 0
# Epoch 55/100
# 10/10 [==============================] - 7s 721ms/step - loss: 0.1708 - accuracy: 0.9373 - precision: 0.9462 - recall: 0.9373 - f1_score: 0.9436 - val_loss: 3.3652 - val_accuracy: 0.5500 - val_precision: 0.5500 - val_recall: 0.5500 - val_f1_score: 0.4882
# Epoch 56/100
# 10/10 [==============================] - 7s 733ms/step - loss: 0.1600 - accuracy: 0.9404 - precision: 0.9490 - recall: 0.9342 - f1_score: 0.9443 - val_loss: 2.9613 - val_accuracy: 0.6250 - val_precision: 0.6234 - val_recall: 0.6000 - val_f1_score: 0.5954
# Epoch 57/100
# 10/10 [==============================] - 7s 685ms/step - loss: 0.1514 - accuracy: 0.9467 - precision: 0.9527 - recall: 0.9467 - f1_score: 0.9519 - val_loss: 3.3542 - val_accuracy: 0.6000 - val_precision: 0.6076 - val_recall: 0.6000 - val_f1_score: 0.5590
# Epoch 58/100
# 10/10 [==============================] - 7s 789ms/step - loss: 0.1010 - accuracy: 0.9561 - precision: 0.9591 - recall: 0.9561 - f1_score: 0.9625 - val_loss: 3.6253 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_f1_score: 0.5414
# Epoch 59/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.1081 - accuracy: 0.9624 - precision: 0.9651 - recall: 0.9530 - f1_score: 0.9684 - val_loss: 3.7221 - val_accuracy: 0.5875 - val_precision: 0.5875 - val_recall: 0.5875 - val_f1_score: 0.5521
# Epoch 60/100
# 10/10 [==============================] - 6s 645ms/step - loss: 0.1417 - accuracy: 0.9467 - precision: 0.9524 - recall: 0.9404 - f1_score: 0.9562 - val_loss: 3.1751 - val_accuracy: 0.5375 - val_precision: 0.5526 - val_recall: 0.5250 - val_f1_score: 0.5559
# Epoch 61/100
# 10/10 [==============================] - 7s 730ms/step - loss: 0.1196 - accuracy: 0.9561 - precision: 0.9560 - recall: 0.9530 - f1_score: 0.9606 - val_loss: 3.5665 - val_accuracy: 0.5625 - val_precision: 0.5584 - val_recall: 0.5375 - val_f1_score: 0.5720
# Epoch 62/100
# 10/10 [==============================] - 7s 701ms/step - loss: 0.1472 - accuracy: 0.9624 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9672 - val_loss: 3.4295 - val_accuracy: 0.5875 - val_precision: 0.6053 - val_recall: 0.5750 - val_f1_score: 0.5852
# Epoch 63/100
# 10/10 [==============================] - 7s 676ms/step - loss: 0.1682 - accuracy: 0.9404 - precision: 0.9430 - recall: 0.9342 - f1_score: 0.9404 - val_loss: 4.2722 - val_accuracy: 0.5500 - val_precision: 0.5570 - val_recall: 0.5500 - val_f1_score: 0.5015
# Epoch 64/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.
- accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - f1_score: 0.9596 - val_loss: 4.7726 - val_accuracy: 0.4875 - val_precision: 0.4937 - val_recall: 0.4875 - val_f1_score: 0.4811
# Epoch 77/100
# 10/10 [==============================] - 6s 599ms/step - loss: 0.1346 - accuracy: 0.9498 - precision: 0.9527 - recall: 0.9467 - f1_score: 0.9477 - val_loss: 3.8516 - val_accuracy: 0.4875 - val_precision: 0.4937 - val_recall: 0.4875 - val_f1_score: 0.4689
# Epoch 78/100
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1037 - accuracy: 0.9655 - precision: 0.9653 - recall: 0.9592 - f1_score: 0.9704 - val_loss: 2.9248 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_f1_score: 0.5652
# Epoch 79/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.1251 - accuracy: 0.9624 - precision: 0.9653 - recall: 0.9592 - f1_score: 0.9625 - val_loss: 3.1677 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5296
# Epoch 80/100
# 10/10 [==============================] - 6s 615ms/step - loss: 0.1343 - accuracy: 0.9624 - precision: 0.9685 - recall: 0.9624 - f1_score: 0.9634 - val_loss: 3.2824 - val_accuracy: 0.5250 - val_precision: 0.5316 - val_recall: 0.5250 - val_f1_score: 0.5201
# Epoch 81/100
# 10/10 [==============================] - 6s 570ms/step - loss: 0.1136 - accuracy: 0.9561 - precision: 0.9621 - recall: 0.9561 - f1_score: 0.9625 - val_loss: 3.1092 - val_accuracy: 0.4875 - val_precision: 0.4875 - val_recall: 0.4875 - val_f1_score: 0.5068
# Epoch 82/100
# 10/10 [==============================] - 7s 709ms/step - loss: 0.1294 - accuracy: 0.9624 - precision: 0.9621 - recall: 0.9561 - f1_score: 0.9673 - val_loss: 3.4700 - val_accuracy: 0.5125 - val_precision: 0.5125 - val_recall: 0.5125 - val_f1_score: 0.5090
# Epoch 83/100
# 10/10 [==============================] - 7s 734ms/step - loss: 0.1252 - accuracy: 0.9530 - precision: 0.9557 - recall: 0.9467 - f1_score: 0.9593 - val_loss: 3.0016 - val_accuracy: 0.5000 - val_precision: 0.5063 - val_recall: 0.5000 - val_f1_score: 0.5515
# Epoch 84/100
# 10/10 [==============================] - 7s 684ms/step - loss: 0.0962 - accuracy: 0.9624 - precision: 0.9653 - recall: 0.9592 - f1_score: 0.9668 - val_loss: 3.4847 - val_accuracy: 0.5125 - val_precision: 0.5190 - val_recall: 0.5125 - val_f1_score: 0.5226
# Epoch 85/100
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0963 - accuracy: 0.9592 - precision: 0.9623 - recall: 0.9592 - f1_score: 0.9590 - val_loss: 3.2272 - val_accuracy: 0.5875 - val_precision: 0.5875 - val_recall: 0.5875 - val_f1_score: 0.5673
# Epoch 86/100
# 10/10 [==============================] - 6s 612ms/step - loss: 0.0827 - accuracy: 0.9687 - precision: 0.9715 - recall: 0.9624 - f1_score: 0.9695 - val_loss: 4.0454 - val_accuracy: 0.4625 - val_precision: 0.4625 - val_recall: 0.4625 - val_f1_score: 0.4552
# Epoch 87/100
# 10/10 [==============================] - 6s 672ms/step - loss: 0.1257 - accuracy: 0.9718 - precision: 0.9717 - recall: 0.9687 - f1_score: 0.9643 - val_loss: 3.6215 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_f1_score: 0.4831
# Epoch 88/100
# 10/10 [==============================] - 7s 679ms/step - loss: 0.0665 - accuracy: 0.9875 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9887 - val_loss: 3.8287 - val_accuracy: 0.4875 - val_precision: 0.5000 - val_recall: 0.4875 - val_f1_score: 0.4399
# Epoch 89/100
# 10/10 [==============================] - 5s 550ms/step - loss: 0.1057 - accuracy: 0.9655 - precision: 0.9685 - recall: 0.9624 - f1_score: 0.9669 - val_loss: 3.3574 - val_accuracy: 0.5000 - val_precision: 0.5128 - val_recall: 0.5000 - val_f1_score: 0.4714
# Epoch 90/100
# 10/10 [==============================] - 6s 617ms/step - loss: 0.1127 - accuracy: 0.9561 - precision: 0.9561 - recall: 0.9561 - f1_score: 0.9540 - val_loss: 3.2094 - val_accuracy: 0.5375 - val_precision: 0.5443 - val_recall: 0.5375 - val_f1_score: 0.4914
# Epoch 91/100
# 10/10 [==============================] - 7s 641ms/step - loss: 0.1388 - accuracy: 0.9687 - precision: 0.9687 - recall: 0.9687 - f1_score: 0.9732 - val_loss: 3.0881 - val_accuracy: 0.5375 - val_precision: 0.5513 - val_recall: 0.5375 - val_f1_score: 0.5332
# Epoch 92/100
# 10/10 [==============================] - 6s 609ms/step - loss: 0.0954 - accuracy: 0.9655 - precision: 0.9685 - recall: 0.9624 - f1_score: 0.9680 - val_loss: 2.7834 - val_accuracy: 0.5250 - val_precision: 0.5316 - val_recall: 0.5250 - val_f1_score: 0.5515
# Epoch 93/100
# 10/10 [==============================] - 7s 685ms/step - loss: 0.1109 - accuracy: 0.9498 - precision: 0.9586 - recall: 0.9436 - f1_score: 0.9559 - val_loss: 3.0690 - val_accuracy: 0.5250 - val_precision: 0.5385 - val_recall: 0.5250 - val_f1_score: 0.5449
# Epoch 94/100
# 10/10 [==============================] - 7s 647ms/step - loss: 0.0688 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9814 - val_loss: 2.7749 - val_accuracy: 0.5750 - val_precision: 0.5897 - val_recall: 0.5750 - val_f1_score: 0.5713
# Epoch 95/100
# 10/10 [==============================] - 7s 724ms/step - loss: 0.0693 - accuracy: 0.9718 - precision: 0.9717 - recall: 0.9687 - f1_score: 0.9743 - val_loss: 2.8669 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_f1_score: 0.5216
# Epoch 96/100
# 10/10 [==============================] - 6s 673ms/step - loss: 0.0780 - accuracy: 0.9687 - precision: 0.9687 - recall: 0.9687 - f1_score: 0.9720 - val_loss: 3.2023 - val_accuracy: 0.5250 - val_precision: 0.5316 - val_recall: 0.5250 - val_f1_score: 0.5126
# Epoch 97/100
# 10/10 [==============================] - 6s 607ms/step - loss: 0.0945 - accuracy: 0.9624 - precision: 0.9623 - recall: 0.9592 - f1_score: 0.9679 - val_loss: 3.4237 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_f1_score: 0.5378
# Epoch 98/100
# 10/10 [==============================] - 7s 741ms/step - loss: 0.0743 - accuracy: 0.9655 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9705 - val_loss: 3.2255 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5320
# Epoch 99/100
# 10/10 [==============================] - 6s 596ms/step - loss: 0.
# Epoch 10/100
# 10/10 [==============================] - 8s 802ms/step - loss: 0.1336 - accuracy: 0.9467 - precision: 0.9525 - recall: 0.9436 - f1_score: 0.9536 - val_loss: 1.0967 - val_accuracy: 0.7375 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7587
# Epoch 11/100
# 10/10 [==============================] - 5s 550ms/step - loss: 0.1140 - accuracy: 0.9561 - precision: 0.9591 - recall: 0.9561 - f1_score: 0.9566 - val_loss: 0.8167 - val_accuracy: 0.8125 - val_precision: 0.8228 - val_recall: 0.8125 - val_f1_score: 0.8291
# Epoch 12/100
# 10/10 [==============================] - 7s 627ms/step - loss: 0.1213 - accuracy: 0.9561 - precision: 0.9590 - recall: 0.9530 - f1_score: 0.9571 - val_loss: 0.7988 - val_accuracy: 0.8250 - val_precision: 0.8354 - val_recall: 0.8250 - val_f1_score: 0.8568
# Epoch 13/100
# 10/10 [==============================] - 6s 612ms/step - loss: 0.1200 - accuracy: 0.9718 - precision: 0.9718 - recall: 0.9718 - f1_score: 0.9658 - val_loss: 1.1519 - val_accuracy: 0.7125 - val_precision: 0.7089 - val_recall: 0.7000 - val_f1_score: 0.7165
# Epoch 14/100
# 10/10 [==============================] - 6s 595ms/step - loss: 0.1380 - accuracy: 0.9467 - precision: 0.9556 - recall: 0.9436 - f1_score: 0.9419 - val_loss: 0.9460 - val_accuracy: 0.7625 - val_precision: 0.7625 - val_recall: 0.7625 - val_f1_score: 0.7591
# Epoch 15/100
# 10/10 [==============================] - 5s 511ms/step - loss: 0.1303 - accuracy: 0.9530 - precision: 0.9557 - recall: 0.9467 - f1_score: 0.9596 - val_loss: 1.6907 - val_accuracy: 0.7000 - val_precision: 0.7089 - val_recall: 0.7000 - val_f1_score: 0.7091
# Epoch 16/100
# 10/10 [==============================] - 6s 597ms/step - loss: 0.1778 - accuracy: 0.9310 - precision: 0.9367 - recall: 0.9279 - f1_score: 0.9226 - val_loss: 2.0450 - val_accuracy: 0.7000 - val_precision: 0.7000 - val_recall: 0.7000 - val_f1_score: 0.6861
# Epoch 17/100
# 10/10 [==============================] - 7s 681ms/step - loss: 0.1817 - accuracy: 0.9436 - precision: 0.9554 - recall: 0.9404 - f1_score: 0.9491 - val_loss: 1.5288 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.6978
# Epoch 18/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.1170 - accuracy: 0.9624 - precision: 0.9620 - recall: 0.9530 - f1_score: 0.9570 - val_loss: 2.3046 - val_accuracy: 0.6750 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6766
# Epoch 19/100
# 10/10 [==============================] - 7s 732ms/step - loss: 0.1013 - accuracy: 0.9687 - precision: 0.9778 - recall: 0.9655 - f1_score: 0.9614 - val_loss: 2.1308 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.6193
# Epoch 20/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.0594 - accuracy: 0.9812 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9844 - val_loss: 1.4439 - val_accuracy: 0.6750 - val_precision: 0.6835 - val_recall: 0.6750 - val_f1_score: 0.6954
# Epoch 21/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.0907 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9784 - val_loss: 1.3832 - val_accuracy: 0.7250 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.7438
# Epoch 22/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.1269 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - f1_score: 0.9681 - val_loss: 1.3398 - val_accuracy: 0.7500 - val_precision: 0.7436 - val_recall: 0.7250 - val_f1_score: 0.7813
# Epoch 23/100
# 10/10 [==============================] - 5s 480ms/step - loss: 0.0699 - accuracy: 0.9749 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9763 - val_loss: 1.3628 - val_accuracy: 0.7375 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7509
# Epoch 24/100
# 10/10 [==============================] - 7s 688ms/step - loss: 0.0970 - accuracy: 0.9655 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9662 - val_loss: 1.4624 - val_accuracy: 0.6750 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6442
# Epoch 25/100
# 10/10 [==============================] - 7s 658ms/step - loss: 0.1065 - accuracy: 0.9592 - precision: 0.9651 - recall: 0.9530 - f1_score: 0.9655 - val_loss: 1.0804 - val_accuracy: 0.7750 - val_precision: 0.7848 - val_recall: 0.7750 - val_f1_score: 0.7835
# Epoch 26/100
# 10/10 [==============================] - 6s 555ms/step - loss: 0.0678 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9779 - val_loss: 1.5733 - val_accuracy: 0.7375 - val_precision: 0.7375 - val_recall: 0.7375 - val_f1_score: 0.7422
# Epoch 27/100
# 10/10 [==============================] - 7s 705ms/step - loss: 0.0809 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - f1_score: 0.9695 - val_loss: 1.8402 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.7051
# Epoch 28/100
# 10/10 [==============================] - 5s 469ms/step - loss: 0.0754 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9744 - val_loss: 1.2696 - val_accuracy: 0.7875 - val_precision: 0.7875 - val_recall: 0.7875 - val_f1_score: 0.7983
# Epoch 29/100
# 10/10 [==============================] - 5s 462ms/step - loss: 0.0806 - accuracy: 0.9749 - precision: 0.9779 - recall: 0.9718 - f1_score: 0.9756 - val_loss: 1.5939 - val_accuracy: 0.7625 - val_precision: 0.7821 - val_recall: 0.7625 - val_f1_score: 0.7767
# Epoch 30/100
# 10/10 [==============================] - 6s 643ms/step - loss: 0.0711 - accuracy: 0.9781 - precision: 0.9873 - recall: 0.9781 - f1_score: 0.9801 - val_loss: 1.5806 - val_accuracy: 0.7125 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.7320
# Epoch 31/100
# 10/10 [==============================] - 6s 613ms/step - loss: 0.0526 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9861 - val_loss: 1.3944 - val_accuracy: 0.7375 - val_precision: 0.7403 - val_recall: 0.7125 - val_f1_score: 0.7538
# Epoch 32/100
# 10/10 [==============================] - 5s 511ms/step - loss: 0.0840 - accuracy: 0.9718 - precision: 0.9718 - recall: 0.9718 - f1_score: 0.9737 - val_loss: 1.6901 - val_accuracy: 0.7000 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.6858
# Epoch 33/100
# 10/10 [==============================] - 6s 565ms/step - loss: 0.1196 - accuracy: 0.9592 - precision: 0.9592 - recall: 0.9592 - f1_score: 0.9631 - val_loss: 2.2793 - val_accuracy: 0.6875 - val_precision: 0.6835 - val_recall: 0.6750 - val_f1_score: 0.7048
# Epoch 34/100
# 10/10 [==============================] - 6s 648ms/step - loss: 0.0879 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - f1_score: 0.9497 - val_loss: 1.9907 - val_accuracy: 0.6750 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6794
# Epoch 35/100
# 10/10 [==============================] - 5s 562ms/step - loss: 0.1744 - accuracy: 0.9498 - precision: 0.9495 - recall: 0.9436 - f1_score: 0.9566 - val_loss: 1.2067 - val_accuracy: 0.6875 - val_precision: 0.6835 - val_recall: 0.6750 - val_f1_score: 0.6975
# Epoch 36/100
# 10/10 [==============================] - 6s 654ms/step - loss: 0.1455 - accuracy: 0.9530 - precision: 0.9553 - recall: 0.9373 - f1_score: 0.9561 - val_loss: 1.7179 - val_accuracy: 0.6500 - val_precision: 0.6456 - val_recall: 0.6375 - val_f1_score: 0.6317
# Epoch 37/100
# 10/10 [==============================] - 5s 530ms/step - loss: 0.0585 - accuracy: 0.9781 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9789 - val_loss: 2.2934 - val_accuracy: 0.5875 - val_precision: 0.5974 - val_recall: 0.5750 - val_f1_score: 0.5916
# Epoch 38/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.0628 - accuracy: 0.9749 - precision: 0.9779 - recall: 0.9718 - f1_score: 0.9769 - val_loss: 2.6656 - val_accuracy: 0.5875 - val_precision: 0.5823 - val_recall: 0.5750 - val_f1_score: 0.5911
# Epoch 39/100
# 10/10 [==============================] - 5s 556ms/step - loss: 0.0940 - accuracy: 0.9655 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9653 - val_loss: 1.8803 - val_accuracy: 0.6625 - val_precision: 0.6667 - val_recall: 0.6500 - val_f1_score: 0.6497
# Epoch 40/100
# 10/10 [==============================] - 6s 639ms/step - loss: 0.0785 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9781 - val_loss: 2.2983 - val_accuracy: 0.6125 - val_precision: 0.6125 - val_recall: 0.6125 - val_f1_score: 0.6150
# Epoch 41/100
# 10/10 [==============================] - 6s 593ms/step - loss: 0.0821 - accuracy: 0.9655 - precision: 0.9778 - recall: 0.9655 - f1_score: 0.9678 - val_loss: 1.2547 - val_accuracy: 0.7000 - val_precision: 0.7000 - val_recall: 0.7000 - val_f1_score: 0.6987
# Epoch 42/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0691 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9818 - val_loss: 1.3863 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.6607
# Epoch 43/100
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0852 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - f1_score: 0.9737 - val_loss: 1.8374 - val_accuracy: 0.6750 - val_precision: 0.6750 - val_recall: 0.6750 - val_f1_score: 0.6257
# Epoch 44/100
# 10/10 [==============================] - 5s 539ms/step - loss: 0.0358 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9928 - val_loss: 1.0180 - val_accuracy: 0.7750 - val_precision: 0.7821 - val_recall: 0.7625 - val_f1_score: 0.7729
# Epoch 45/100
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0574 - accuracy: 0.9781 - precision: 0.9842 - recall: 0.9781 - f1_score: 0.9813 - val_loss: 1.4489 - val_accuracy: 0.7000 - val_precision: 0.7000 - val_recall: 0.7000 - val_f1_score: 0.6893
# Epoch 46/100
# 10/10 [==============================] - 6s 575ms/step - loss: 0.0286 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9893 - val_loss: 1.5016 - val_accuracy: 0.7125 - val_precision: 0.7125 - val_recall: 0.7125 - val_f1_score: 0.7177
# Epoch 47/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0390 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9901 - val_loss: 2.3480 - val_accuracy: 0.6750 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6792
# Epoch 48/100
# 10/10 [==============================] - 5s 570ms/step - loss: 0.0525 - accuracy: 0.9812 - precision: 0.9842 - recall: 0.9781 - f1_score: 0.9847 - val_loss: 1.6764 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_f1_score: 0.6997
# Epoch 49/100
# 10/10 [==============================] - 6s 587ms/step - loss: 0.1433 - accuracy: 0.9498 - precision: 0.9527 - recall: 0.9467 - f1_score: 0.9578 - val_loss: 0.8495 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_f1_score: 0.7934
# Epoch 50/100
# 10/10 [==============================] - 6s 596ms/step - loss: 0.0968 - accuracy: 0.9687 - precision: 0.9748 - recall: 0.9687 - f1_score: 0.9726 - val_loss: 1.0013 - val_accuracy: 0.7625 - val_precision: 0.7625 - val_recall: 0.7625 - val_f1_score: 0.7605
# Epoch 51/100
# 10/10 [==============================] - 6s 594ms/step - loss: 0.0871 - accuracy: 0.9687 - precision: 0.9715 - recall: 0.9624 - f1_score: 0.9718 - val_loss: 1.7575 - val_accuracy: 0.6625 - val_precision: 0.6883 - val_recall: 0.6625 - val_f1_score: 0.6661
# Epoch 52/100
# 10/10 [==============================] - 6s 513ms/step - loss: 0.1053 - accuracy: 0.9687 - precision: 0.9687 - recall: 0.9687 - f1_score: 0.9670 - val_loss: 1.6237 - val_accuracy: 0.7500 - val_precision: 0.7468 - val_recall: 0.7375 - val_f1_score: 0.7732
# Epoch 53/100
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0757 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9784 - val_loss: 1.8282 - val_accuracy: 0.6500 - val_precision: 0.6753 - val_recall: 0.6500 - val_f1_score: 0.6688
# Epoch 54/100
# 10/10 [==============================] - 6s 623ms/step - loss: 0.0459 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9875 - f1_score: 0.9886 - val_loss: 1.6245 - val_accuracy: 0.6875 - val_precision: 0.6923 - val_recall: 0.6750 - val_f1_score: 0.7022
# Epoch 55/100
# 10/10 [==============================] - 5s 556ms/step - loss: 0.0687 - accuracy: 0.9718 - precision: 0.9718 - recall: 0.9718 - f1_score: 0.9752 - val_loss: 2.0614 - val_accuracy: 0.6500 - val_precision: 0.6753 - val_recall: 0.6500 - val_f1_score: 0.6630
# Epoch 56/100
# 10/10 [==============================] - 5s 529ms/step - loss: 0.0600 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - f1_score: 0.9790 - val_loss: 1.6152 - val_accuracy: 0.7625 - val_precision: 0.7821 - val_recall: 0.7625 - val_f1_score: 0.7820
# Epoch 57/100
# 10/10 [==============================] - 5s 520ms/step - loss: 0.0886 - accuracy: 0.9749 - precision: 0.9748 - recall: 0.9687 - f1_score: 0.9767 - val_loss: 1.4976 - val_accuracy: 0.7750 - val_precision: 0.7750 - val_recall: 0.7750 - val_f1_score: 0.7982
# Epoch 58/100
# 10/10 [==============================] - 6s 649ms/step - loss: 0.1074 - accuracy: 0.9655 - precision: 0.9653 - recall: 0.9592 - f1_score: 0.9675 - val_loss: 1.4605 - val_accuracy: 0.7750 - val_precision: 0.8052 - val_recall: 0.7750 - val_f1_score: 0.8063
# Epoch 59/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0552 - accuracy: 0.9781 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9794 - val_loss: 1.0023 - val_accuracy: 0.8250 - val_precision: 0.8250 - val_recall: 0.8250 - val_f1_score: 0.8349
# Epoch 60/100
# 10/10 [==============================] - 5s 511ms/step - loss: 0.1030 - accuracy: 0.9624 - precision: 0.9653 - recall: 0.9592 - f1_score: 0.9640 - val_loss: 1.5638 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_f1_score: 0.8247
# Epoch 61/100
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0391 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9878 - val_loss: 2.2486 - val_accuracy: 0.7125 - val_precision: 0.7308 - val_recall: 0.7125 - val_f1_score: 0.7379
# Epoch 62/100
# 10/10 [==============================] - 5s 554ms/step - loss: 0.0686 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - f1_score: 0.9760 - val_loss: 2.2329 - val_accuracy: 0.7000 - val_precision: 0.7089 - val_recall: 0.7000 - val_f1_score: 0.6979
# Epoch 63/100
# 10/10 [==============================] - 5s 558ms/step - loss: 0.0571 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9772 - val_loss: 2.4901 - val_accuracy: 0.6875 - val_precision: 0.6923 - val_recall: 0.6750 - val_f1_score: 0.7137
# Epoch 64/100
# 10/10 [==============================] - 5s 516ms/step - loss: 0.0903 - accuracy: 0.9718 - precision: 0.9718 - recall: 0.9718 - f1_score: 0.9732 - val_loss: 2.3722 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_f1_score: 0.7075
# Epoch 65/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.1021 - accuracy: 0.9624 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9668 - val_loss: 3.9922 - val_accuracy: 0.5625 - val_precision: 0.5769 - val_recall: 0.5625 - val_f1_score: 0.5690
# Epoch 66/100
# 10/10 [==============================] - 6s 565ms/step - loss: 0.1019 - accuracy: 0.9655 - precision: 0.9716 - recall: 0.9655 - f1_score: 0.9707 - val_loss: 3.0698 - val_accuracy: 0.6125 - val_precision: 0.6203 - val_recall: 0.6125 - val_f1_score: 0.6395
# Epoch 67/100
# 10/10 [==============================] - 6s 659ms/step - loss: 0.0468 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - f1_score: 0.9798 - val_loss: 2.6643 - val_accuracy: 0.6250 - val_precision: 0.6203 - val_recall: 0.6125 - val_f1_score: 0.6376
# Epoch 68/100
# 10/10 [==============================] - 6s 652ms/step - loss: 0.0531 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9900 - val_loss: 2.6228 - val_accuracy: 0.6375 - val_precision: 0.6456 - val_recall: 0.6375 - val_f1_score: 0.6585
# Epoch 69/100
# 10/10 [==============================] - 5s 517ms/step - loss: 0.0458 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9840 - val_loss: 3.0971 - val_accuracy: 0.5500 - val_precision: 0.5570 - val_recall: 0.5500 - val_f1_score: 0.5532
# Epoch 70/100
# 10/10 [==============================] - 5s 522ms/step - loss: 0.0415 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9881 - val_loss: 1.8968 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.6291
# Epoch 71/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.0618 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9863 - val_loss: 1.4740 - val_accuracy: 0.6375 - val_precision: 0.6538 - val_recall: 0.6375 - val_f1_score: 0.6118
# Epoch 72/100
# 10/10 [==============================] - 6s 603ms/step - loss: 0.0408 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9839 - val_loss: 1.6830 - val_accuracy: 0.6750 - val_precision: 0.6835 - val_recall: 0.6750 - val_f1_score: 0.6781
# Epoch 73/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.0428 - accuracy: 0.9781 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9791 - val_loss: 2.0881 - val_accuracy: 0.6625 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6724
# Epoch 74/100
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0414 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9878 - val_loss: 2.1513 - val_accuracy: 0.6250 - val_precision: 0.6329 - val_recall: 0.6250 - val_f1_score: 0.6331
# Epoch 75/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0686 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - f1_score: 0.9807 - val_loss: 1.3052 - val_accuracy: 0.7375 - val_precision: 0.7468 - val_recall: 0.7375 - val_f1_score: 0.7563
# Epoch 76/100
# 10/10 [==============================] - 7s 665ms/step - loss: 0.0495 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9908 - val_loss: 1.4503 - val_accuracy: 0.7250 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7247
# Epoch 77/100
# 10/10 [==============================] - 5s 533ms/step - loss: 0.0466 - accuracy: 0.9781 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9830 - val_loss: 1.6728 - val_accuracy: 0.7250 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7297
# Epoch 78/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0319 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9898 - val_loss: 1.1744 - val_accuracy: 0.7625 - val_precision: 0.7821 - val_recall: 0.7625 - val_f1_score: 0.7677
# Epoch 79/100
# ...
# Epoch 42/100
# 10/10 [==============================] - 4s 445ms/step - loss: 0.0138 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9941 - val_loss: 0.2333 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.8863
# Epoch 43/100
# 10/10 [==============================] - 5s 508ms/step - loss: 0.0389 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9830 - val_loss: 0.2325 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9025
# Epoch 44/100
# 10/10 [==============================] - 4s 434ms/step - loss: 0.0075 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.3158 - val_accuracy: 0.9114 - val_precision: 0.9231 - val_recall: 0.9114 - val_f1_score: 0.8876
# Epoch 45/100
# 10/10 [==============================] - 5s 477ms/step - loss: 0.0084 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.8851
# Epoch 46/100
# 10/10 [==============================] - 4s 434ms/step - loss: 0.0023 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.3285 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8635
# Epoch 47/100
# 10/10 [==============================] - 5s 483ms/step - loss: 0.0127 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9971 - val_loss: 0.2908 - val_accuracy: 0.9114 - val_precision: 0.9231 - val_recall: 0.9114 - val_f1_score: 0.8837
# Epoch 48/100
# 10/10 [==============================] - 5s 486ms/step - loss: 0.0180 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9946 - val_loss: 0.1960 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9146
# Epoch 49/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.0202 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9882 - val_loss: 0.1341 - val_accuracy: 0.9494 - val_precision: 0.9615 - val_recall: 0.9494 - val_f1_score: 0.9451
# Epoch 50/100
# 10/10 [==============================] - 5s 482ms/step - loss: 0.0052 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9296
# Epoch 51/100
# 10/10 [==============================] - 5s 463ms/step - loss: 0.0175 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9879 - val_loss: 0.2794 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9242
# Epoch 52/100
# 10/10 [==============================] - 5s 470ms/step - loss: 0.0193 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9915 - val_loss: 0.1524 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9413
# Epoch 53/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0174 - accuracy: 0.9937 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9939 - val_loss: 0.1662 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9196
# Epoch 54/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0105 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9941 - val_loss: 0.1940 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9492
# Epoch 55/100
# 10/10 [==============================] - 4s 430ms/step - loss: 0.0732 - accuracy: 0.9844 - precision: 0.9844 - recall: 0.9844 - f1_score: 0.9855 - val_loss: 0.1581 - val_accuracy: 0.9747 - val_precision: 0.9747 - val_recall: 0.9747 - val_f1_score: 0.9715
# Epoch 56/100
# 10/10 [==============================] - 5s 477ms/step - loss: 0.0140 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9940 - val_loss: 0.5076 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8596
# Epoch 57/100
# 10/10 [==============================] - 4s 450ms/step - loss: 0.0179 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9949 - val_loss: 1.0490 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8765
# Epoch 58/100
# 10/10 [==============================] - 4s 464ms/step - loss: 0.0260 - accuracy: 0.9937 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9905 - val_loss: 1.1666 - val_accuracy: 0.8101 - val_precision: 0.8101 - val_recall: 0.8101 - val_f1_score: 0.8103
# Epoch 59/100
# 10/10 [==============================] - 5s 479ms/step - loss: 0.0748 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9781 - f1_score: 0.9807 - val_loss: 0.4112 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.9033
# Epoch 60/100
# 10/10 [==============================] - 4s 433ms/step - loss: 0.0099 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9969 - f1_score: 1.0000 - val_loss: 0.4868 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.9012
# Epoch 61/100
# 10/10 [==============================] - 5s 478ms/step - loss: 0.0235 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9875 - f1_score: 0.9919 - val_loss: 0.6601 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8869
# Epoch 62/100
# 10/10 [==============================] - 5s 493ms/step - loss: 0.0212 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9890 - val_loss: 0.5993 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8869
# Epoch 63/100
# 10/10 [==============================] - 5s 480ms/step - loss: 0.0119 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9971 - val_loss: 0.4911 - val_accuracy: 0.8861 - val_precision: 0.8974 - val_recall: 0.8861 - val_f1_score: 0.8966
# Epoch 64/100
# 10/10 [==============================] - 5s 502ms/step - loss: 0.0540 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9837 - val_loss: 0.1896 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9505
# Epoch 65/100
# 10/10 [==============================] - 4s 462ms/step - loss: 0.0145 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9975 - val_loss: 0.3794 - val_accuracy: 0.8608 - val_precision: 0.8947 - val_recall: 0.8608 - val_f1_score: 0.8348
# Epoch 66/100
# 10/10 [==============================] - 5s 482ms/step - loss: 0.0299 - accuracy: 0.9844 - precision: 0.9844 - recall: 0.9844 - f1_score: 0.9871 - val_loss: 0.6245 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8462
# Epoch 67/100
# 10/10 [==============================] - 5s 502ms/step - loss: 0.0281 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9893 - val_loss: 0.7973 - val_accuracy: 0.8354 - val_precision: 0.8333 - val_recall: 0.8228 - val_f1_score: 0.8055
# Epoch 68/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0094 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.5127 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8199
# Epoch 69/100
# 10/10 [==============================] - 4s 455ms/step - loss: 0.0104 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6209 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_f1_score: 0.8465
# Epoch 70/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0070 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9975 - val_loss: 0.7342 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8661
# Epoch 71/100
# 10/10 [==============================] - 4s 449ms/step - loss: 0.0420 - accuracy: 0.9844 - precision: 0.9844 - recall: 0.9844 - f1_score: 0.9875 - val_loss: 0.5360 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_f1_score: 0.8769
# Epoch 72/100
# 10/10 [==============================] - 5s 489ms/step - loss: 0.0096 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9946 - val_loss: 0.6973 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_f1_score: 0.8712
# Epoch 73/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0094 - accuracy: 0.9969 - precision: 1.0000 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.5957 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8895
# Epoch 74/100
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0460 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9939 - val_loss: 0.5302 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.8998
# Epoch 75/100
# 10/10 [==============================] - 5s 546ms/step - loss: 0.0100 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9974 - val_loss: 0.3718 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.9020
# Epoch 76/100
# 10/10 [==============================] - 5s 441ms/step - loss: 0.0205 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9921 - val_loss: 0.4915 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8902
# Epoch 77/100
# 10/10 [==============================] - 5s 474ms/step - loss: 0.0154 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9941 - val_loss: 0.6858 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_f1_score: 0.8120
# Epoch 78/100
# 10/10 [==============================] - 5s 471ms/step - loss: 0.0219 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9886 - val_loss: 1.0596 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_f1_score: 0.8270
# Epoch 79/100
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0160 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9940 - val_loss: 1.1661 - val_accuracy: 0.8354 - val_precision: 0.8462 - val_recall: 0.8354 - val_f1_score: 0.8068
# Epoch 80/100
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0505 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 1.2755 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_f1_score: 0.7937
# Epoch 81/100
# 10/10 [==============================] - 5s 471ms/step - loss: 0.0362 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9890 - val_loss: 1.4405 - val_accuracy: 0.7848 - val_precision: 0.7848 - val_recall: 0.7848 - val_f1_score: 0.7441
# Epoch 82/100
# 10/10 [==============================] - 4s 416ms/step - loss: 0.0221 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9911 - val_loss: 1.2904 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_f1_score: 0.7845
# Epoch 83/100
# 10/10 [==============================] - 5s 487ms/step - loss: 0.0553 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9910 - val_loss: 1.0463 - val_accuracy: 0.7975 - val_precision: 0.7975 - val_recall: 0.7975 - val_f1_score: 0.7838
# Epoch 84/100
# 10/10 [==============================] - 5s 482ms/step - loss: 0.0180 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9969 - val_loss: 0.6199 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_f1_score: 0.8272
# Epoch 85/100
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0078 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.4238 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8445
# Epoch 86/100
# 10/10 [==============================] - 5s 460ms/step - loss: 0.0151 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9909 - val_loss: 0.3773 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.8932
# Epoch 87/100
# 10/10 [==============================] - 4s 440ms/step - loss: 0.0142 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9941 - val_loss: 0.2217 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9437
# Epoch 88/100
# 10/10 [==============================] - 4s 426ms/step - loss: 0.0119 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.2454 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9258
# Epoch 89/100
# 10/10 [==============================] - 4s 443ms/step - loss: 0.0086 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9975 - val_loss: 0.3059 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8587
# Epoch 90/100
# 10/10 [==============================] - 4s 432ms/step - loss: 0.0215 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9916 - val_loss: 0.3674 - val_accuracy: 0.8987 - val_precision: 0.9103 - val_recall: 0.8987 - val_f1_score: 0.8883
# Epoch 91/100
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0110 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9949 - val_loss: 0.7450 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_f1_score: 0.8008
# Epoch 92/100
# 10/10 [==============================] - 5s 476ms/step - loss: 0.0099 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.5496 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8517
# Epoch 93/100
# 10/10 [==============================] - 5s 469ms/step - loss: 0.0048 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.4813 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8517
# Epoch 94/100
# 10/10 [==============================] - 4s 439ms/step - loss: 0.0249 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9944 - val_loss: 0.3289 - val_accuracy: 0.9114 - val_precision: 0.9231 - val_recall: 0.9114 - val_f1_score: 0.9234
# Epoch 95/100
# 10/10 [==============================] - 4s 428ms/step - loss: 0.0351 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9919 - val_loss: 0.4116 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_f1_score: 0.8719
# Epoch 96/100
# 10/10 [==============================] - 4s 418ms/step - loss: 0.0137 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9950 - val_loss: 0.7417 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_f1_score: 0.8536
# Epoch 97/100
# 10/10 [==============================] - 5s 479ms/step - loss: 0.0139 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9942 - val_loss: 0.8658 - val_accuracy: 0.8101 - val_precision: 0.8101 - val_recall: 0.8101 - val_f1_score: 0.7723
# Epoch 98/100
# 10/10 [==============================] - 4s 432ms/step - loss: 0.0412 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9886 - val_loss: 0.2550 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9151
# Epoch 99/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0084 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9287
# Epoch 100/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0035 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9114 - val_precision: 0.9231 - val_recall: 0.9114 - val_f1_score: 0.9090

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, None, None, 3)     0
#
#  lambda (Lambda)             (None, None, None, 3)     0
#
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  spatial_attention (SpatialA  (None, None, None, 2048)  3
#  ttention)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 59,423,113
# Trainable params: 18,002,697
# Non-trainable params: 41,420,416
# _________________________________________________________________

# %%
combined_history = {}
for metric in history_list[0].keys():
    combined_history[metric] = []
    for hist in history_list:
        combined_history[metric].extend(hist[metric])

# Plot the combined history
plt.plot(combined_history['loss'])
plt.plot(combined_history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(combined_history['accuracy'])
plt.plot(combined_history['val_accuracy'])
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
test_data_dir = '/content/drive/MyDrive/testdata/testdata/testdata'
test_data_dir = pathlib.Path(test_data_dir)
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)

# convert it to one hot encoded
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, total_classes)))

test_images = []
test_labels = []
for images, labels in test_dataset:
    test_images.append(images.numpy())
    test_labels.append(labels.numpy())

test_images = np.concatenate(test_images)
test_labels = np.concatenate(test_labels)
# Out:
# Found 81 files belonging to 6 classes.

# %%
predictions = model.predict(test_images)
# Out:
# 3/3 [==============================] - 1s 260ms/step

# %%
test_labels = np.argmax(test_labels, axis=-1)
predictions = np.argmax(predictions, axis=-1)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(test_labels, predictions)
precision = precision_score(test_labels, predictions, average='macro')
recall = recall_score(test_labels, predictions, average='macro')
f1 = f1_score(test_labels, predictions, average='macro')

print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1-Score: {f1}")
# Out:
# Test Accuracy: 0.9629629629629629
# Test Precision: 0.9652406417112299
# Test Recall: 0.9620009620009619
# Test F1-Score: 0.9617940953297771

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(test_labels, predictions)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, predictions, target_names=class_names))
# Out:
#                           precision    recall  f1-score   support
#
# Hypertensive retinopathy       0.91      1.00      0.95        10
#            Mild NPDR (1)       1.00      0.89      0.94         9
#        Moderate NPDR (2)       1.00      0.93      0.96        14
#                  NO_DR 0       0.88      1.00      0.94        15
#       Proliferative DR 4       1.00      1.00      1.00        11
#            Severe NPDR 3       1.00      0.95      0.98        22
#
#                 accuracy                           0.96        81
#                macro avg       0.97      0.96      0.96        81
#             weighted avg       0.97      0.96      0.96        81
