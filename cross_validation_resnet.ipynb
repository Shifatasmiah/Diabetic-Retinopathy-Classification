# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifatasmiah/Diabetic-Retinopathy-Classification/blob/main/cross_validation_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.optimizers import Adam
import pathlib
import pickle
from sklearn.model_selection import KFold

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/Diabetic_Retinopathy/retinadataset'
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 399

# %%
img_height, img_width = 224, 224
batch_size = 32
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)
# Out:
# Found 399 files belonging to 6 classes.

# %%
class_names = dataset.class_names
total_classes = len(class_names)
print(total_classes)
print(class_names)
# Out:
# 6
# ['Hypertensive retinopathy', 'Mild NPDR (1)', 'Moderate NPDR (2)', 'NO_DR 0', 'Proliferative DR 4', 'Severe NPDR 3']

# %%
plt.figure(figsize=(10, 10))
for images, labels in dataset.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

dataset = dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %%
# convert it to one hot encoded
dataset = dataset.map(lambda x, y: (x, tf.one_hot(y, total_classes)))

# %%
# checkpoint and monitor val_accuracy val_precision val_recall val_f1_score
model_name = 'ResNet152'
checkpoint_filepath = '/content/drive/MyDrive/Diabetic_Retinopathy/training_checkpoints/' + model_name + '.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose=1,
    period=25
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history_list = []
history_file = "/content/drive/MyDrive/Diabetic_Retinopathy/training_history/" + model_name + ".pkl"
if os.path.exists(history_file):
    with open(history_file, "rb") as f:
        history_list = pickle.load(f)
else:
    history_list = []

# %%
data_augmentation = Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.2),
        layers.RandomBrightness(0.2),
        layers.RandomTranslation(0.2, 0.2, fill_mode="nearest"),
        layers.RandomHeight(0.2),
        layers.RandomWidth(0.2),

    ])

# %%
plt.figure(figsize=(10, 10))
for images, _ in dataset.take(2):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[3].numpy().astype("uint8"))
        plt.axis("off")

# %%
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
if os.path.exists(checkpoint_filepath):
    # Load the model from the checkpoint file
    model = tf.keras.saving.load_model(checkpoint_filepath)
    print("Model loaded from checkpoint.")
else:
    pretrained_model = tf.keras.applications.ResNet152(include_top=False,
                                                            input_shape=(
                                                                img_height, img_width, 3),
                                                            pooling='avg', classes=total_classes,
                                                            weights='imagenet')

    for layer in pretrained_model.layers[:-50]:
        layer.trainable = False


    model = Sequential([
        data_augmentation,
        layers.Lambda(tf.keras.applications.resnet.preprocess_input),
        pretrained_model,
        Flatten(),
        Dense(512, activation='relu'),
        Dense(total_classes, activation='softmax'),
    ])

    model.build((None, img_height, img_width, 3))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 2s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, None, None, 3)     0
#
#  lambda (Lambda)             (None, None, None, 3)     0
#
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 59,423,110
# Trainable params: 18,002,694
# Non-trainable params: 41,420,416
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy', metrics=[
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tfa.metrics.F1Score(total_classes,name = 'f1_score')
])

# %%
train_images = []
train_labels = []
for images, labels in dataset:
    train_images.append(images.numpy())
    train_labels.append(labels.numpy())

train_images = np.concatenate(train_images)
train_labels = np.concatenate(train_labels)

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=123)

fold = 1
for train_index, val_index in kf.split(train_images):
    print(f"Training fold: {fold}")
    x_train, x_val = train_images[train_index], train_images[val_index]
    y_train, y_val = train_labels[train_index], train_labels[val_index]
    train_fold = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size)
    val_fold = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

    epochs = 100
    history = model.fit(
    train_fold,
    validation_data=val_fold,
    epochs=epochs,
    #callbacks=[model_checkpoint_callback],
    )

    fold += 1

    history_list.append(history.history)

#with open(history_file, "wb") as f:
   # pickle.dump(history_list, f)
# Out:
# Training fold: 1
# Epoch 1/100
# 10/10 [==============================] - 56s 3s/step - loss: 2.3325 - accuracy: 0.3166 - precision: 0.3261 - recall: 0.1411 - f1_score: 0.2516 - val_loss: 7.8947 - val_accuracy: 0.2750 - val_precision: 0.2658 - val_recall: 0.2625 - val_f1_score: 0.1579
# Epoch 2/100
# 10/10 [==============================] - 20s 2s/step - loss: 1.4210 - accuracy: 0.4295 - precision: 0.5900 - recall: 0.1850 - f1_score: 0.3177 - val_loss: 87.7425 - val_accuracy: 0.2375 - val_precision: 0.2405 - val_recall: 0.2375 - val_f1_score: 0.0931
# Epoch 3/100
# 10/10 [==============================] - 18s 2s/step - loss: 1.2350 - accuracy: 0.4984 - precision: 0.6291 - recall: 0.2978 - f1_score: 0.4526 - val_loss: 15.5639 - val_accuracy: 0.2375 - val_precision: 0.2436 - val_recall: 0.2375 - val_f1_score: 0.0937
# Epoch 4/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.0814 - accuracy: 0.5486 - precision: 0.6872 - recall: 0.3856 - f1_score: 0.5431 - val_loss: 13.6859 - val_accuracy: 0.2625 - val_precision: 0.2658 - val_recall: 0.2625 - val_f1_score: 0.1428
# Epoch 5/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.0148 - accuracy: 0.5799 - precision: 0.7263 - recall: 0.4326 - f1_score: 0.5427 - val_loss: 16.3693 - val_accuracy: 0.2625 - val_precision: 0.2625 - val_recall: 0.2625 - val_f1_score: 0.1267
# Epoch 6/100
# 10/10 [==============================] - 15s 2s/step - loss: 0.9288 - accuracy: 0.6332 - precision: 0.7299 - recall: 0.4828 - f1_score: 0.6397 - val_loss: 13.7998 - val_accuracy: 0.3375 - val_precision: 0.3562 - val_recall: 0.3250 - val_f1_score: 0.2728
# Epoch 7/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.8514 - accuracy: 0.6614 - precision: 0.7593 - recall: 0.5737 - f1_score: 0.6479 - val_loss: 7.7704 - val_accuracy: 0.4000 - val_precision: 0.4156 - val_recall: 0.4000 - val_f1_score: 0.3145
# Epoch 8/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.7317 - accuracy: 0.6959 - precision: 0.7638 - recall: 0.6082 - f1_score: 0.7056 - val_loss: 11.9701 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000 - val_f1_score: 0.1519
# Epoch 9/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.7164 - accuracy: 0.7524 - precision: 0.8015 - recall: 0.6583 - f1_score: 0.7614 - val_loss: 16.2603 - val_accuracy: 0.2750 - val_precision: 0.2750 - val_recall: 0.2750 - val_f1_score: 0.2120
# Epoch 10/100
# 10/10 [==============================] - 13s 1s/step - loss: 0
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0837 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9792 - val_loss: 3.9743 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5940
# Epoch 65/100
# 10/10 [==============================] - 6s 621ms/step - loss: 0.0804 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - f1_score: 0.9800 - val_loss: 4.2932 - val_accuracy: 0.5125 - val_precision: 0.5190 - val_recall: 0.5125 - val_f1_score: 0.5593
# Epoch 66/100
# 10/10 [==============================] - 7s 760ms/step - loss: 0.0941 - accuracy: 0.9655 - precision: 0.9686 - recall: 0.9655 - f1_score: 0.9654 - val_loss: 4.4158 - val_accuracy: 0.5375 - val_precision: 0.5375 - val_recall: 0.5375 - val_f1_score: 0.5727
# Epoch 67/100
# 10/10 [==============================] - 5s 548ms/step - loss: 0.0466 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9908 - val_loss: 4.7464 - val_accuracy: 0.5500 - val_precision: 0.5513 - val_recall: 0.5375 - val_f1_score: 0.5867
# Epoch 68/100
# 10/10 [==============================] - 6s 596ms/step - loss: 0.0806 - accuracy: 0.9718 - precision: 0.9778 - recall: 0.9687 - f1_score: 0.9709 - val_loss: 3.8204 - val_accuracy: 0.5375 - val_precision: 0.5513 - val_recall: 0.5375 - val_f1_score: 0.5538
# Epoch 69/100
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0409 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9812 - f1_score: 0.9858 - val_loss: 4.7547 - val_accuracy: 0.5250 - val_precision: 0.5250 - val_recall: 0.5250 - val_f1_score: 0.5216
# Epoch 70/100
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0612 - accuracy: 0.9687 - precision: 0.9717 - recall: 0.9687 - f1_score: 0.9727 - val_loss: 4.1802 - val_accuracy: 0.5500 - val_precision: 0.5500 - val_recall: 0.5500 - val_f1_score: 0.5764
# Epoch 71/100
# 10/10 [==============================] - 6s 640ms/step - loss: 0.0869 - accuracy: 0.9718 - precision: 0.9746 - recall: 0.9624 - f1_score: 0.9745 - val_loss: 3.5808 - val_accuracy: 0.5375 - val_precision: 0.5375 - val_recall: 0.5375 - val_f1_score: 0.5392
# Epoch 72/100
# 10/10 [==============================] - 6s 668ms/step - loss: 0.0553 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9861 - val_loss: 4.9855 - val_accuracy: 0.5250 - val_precision: 0.5316 - val_recall: 0.5250 - val_f1_score: 0.5395
# Epoch 73/100
# 10/10 [==============================] - 8s 860ms/step - loss: 0.1057 - accuracy: 0.9687 - precision: 0.9778 - recall: 0.9687 - f1_score: 0.9732 - val_loss: 5.1137 - val_accuracy: 0.4750 - val_precision: 0.4750 - val_recall: 0.4750 - val_f1_score: 0.4865
# Epoch 74/100
# 10/10 [==============================] - 5s 546ms/step - loss: 0.0647 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.
- precision: 0.9780 - recall: 0.9749 - f1_score: 0.9801 - val_loss: 4.7386 - val_accuracy: 0.5500 - val_precision: 0.5500 - val_recall: 0.5500 - val_f1_score: 0.5735
# Epoch 89/100
# 10/10 [==============================] - 6s 598ms/step - loss: 0.0640 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9741 - val_loss: 4.5518 - val_accuracy: 0.5875 - val_precision: 0.5823 - val_recall: 0.5750 - val_f1_score: 0.6321
# Epoch 90/100
# 10/10 [==============================] - 6s 649ms/step - loss: 0.0466 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9788 - val_loss: 4.9390 - val_accuracy: 0.6000 - val_precision: 0.6076 - val_recall: 0.6000 - val_f1_score: 0.6185
# Epoch 91/100
# 10/10 [==============================] - 7s 697ms/step - loss: 0.0733 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9787 - val_loss: 4.6100 - val_accuracy: 0.5375 - val_precision: 0.5316 - val_recall: 0.5250 - val_f1_score: 0.5667
# Epoch 92/100
# 10/10 [==============================] - 6s 639ms/step - loss: 0.0524 - accuracy: 0.9875 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9847 - val_loss: 4.3431 - val_accuracy: 0.5875 - val_precision: 0.5875 - val_recall: 0.5875 - val_f1_score: 0.6286
# Epoch 93/100
# 10/10 [==============================] - 5s 512ms/step - loss: 0.0243 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9920 - val_loss: 4.2165 - val_accuracy: 0.5875 - val_precision: 0.5949 - val_recall: 0.5875 - val_f1_score: 0.6309
# Epoch 94/100
# 10/10 [==============================] - 6s 615ms/step - loss: 0.0403 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9888 - val_loss: 5.2835 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.4875 - val_f1_score: 0.5292
# Epoch 95/100
# 10/10 [==============================] - 5s 551ms/step - loss: 0.0349 - accuracy: 0.9906 - precision: 0.9905 - recall: 0.9843 - f1_score: 0.9912 - val_loss: 4.1112 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5831
# Epoch 96/100
# 10/10 [==============================] - 6s 623ms/step - loss: 0.0598 - accuracy: 0.9906 - precision: 0.9905 - recall: 0.9843 - f1_score: 0.9912 - val_loss: 3.7341 - val_accuracy: 0.5750 - val_precision: 0.5823 - val_recall: 0.5750 - val_f1_score: 0.6038
# Epoch 97/100
# 10/10 [==============================] - 6s 642ms/step - loss: 0.0490 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9893 - val_loss: 5.1572 - val_accuracy: 0.5750 - val_precision: 0.5750 - val_recall: 0.5750 - val_f1_score: 0.6010
# Epoch 98/100
# 10/10 [==============================] - 6s 669ms/step - loss: 0.0863 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9754 - val_loss: 4.5138 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_f1_score: 0.5794
# Epoch 99/100
# 10/10 [==============================] - 6s 633ms/step - loss: 0.0326 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9867 - val_loss: 4.9788 - val_accuracy: 0.5625 - val_precision: 0.5641 - val_recall: 0.5500 - val_f1_score: 0.5838
# Epoch 100/100
# 10/10 [==============================] - 5s 511ms/step - loss: 0.0513 - accuracy: 0.9812 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9805 - val_loss: 4.8111 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5865
# Training fold: 2
# Epoch 1/100
# 10/10 [==============================] - 6s 537ms/step - loss: 0.7789 - accuracy: 0.8558 - precision: 0.8686 - recall: 0.8495 - f1_score: 0.8544 - val_loss: 1.4742 - val_accuracy: 0.7625 - val_precision: 0.7792 - val_recall: 0.7500 - val_f1_score: 0.7339
# Epoch 2/100
# 10/10 [==============================] - 5s 562ms/step - loss: 0.4517 - accuracy: 0.8495 - precision: 0.8650 - recall: 0.8433 - f1_score: 0.8539 - val_loss: 6.0722 - val_accuracy: 0.4875 - val_precision: 0.5000 - val_recall: 0.4875 - val_f1_score: 0.3835
# Epoch 3/100
# 10/10 [==============================] - 5s 516ms/step - loss: 0.3168 - accuracy: 0.8903 - precision: 0.9071 - recall: 0.8871 - f1_score: 0.8923 - val_loss: 5.9656 - val_accuracy: 0.4375 - val_precision: 0.4487 - val_recall: 0.4375 - val_f1_score: 0.3419
# Epoch 4/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.2545 - accuracy: 0.9091 - precision: 0.9402 - recall: 0.8871 - f1_score: 0.9119 - val_loss: 5.0300 - val_accuracy: 0.5125 - val_precision: 0.5190 - val_recall: 0.5125 - val_f1_score: 0.3584
# Epoch 5/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.1776 - accuracy: 0.9404 - precision: 0.9583 - recall: 0.9373 - f1_score: 0.9479 - val_loss: 4.4511 - val_accuracy: 0.6000 - val_precision: 0.6076 - val_recall: 0.6000 - val_f1_score: 0.5518
# Epoch 6/100
# 10/10 [==============================] - 5s 544ms/step - loss: 0.1433 - accuracy: 0.9404 - precision: 0.9522 - recall: 0.9373 - f1_score: 0.9435 - val_loss: 4.3370 - val_accuracy: 0.5750 - val_precision: 0.5750 - val_recall: 0.5750 - val_f1_score: 0.5227
# Epoch 7/100
# 10/10 [==============================] - 5s 558ms/step - loss: 0.1343 - accuracy: 0.9530 - precision: 0.9587 - recall: 0.9467 - f1_score: 0.9585 - val_loss: 3.4101 - val_accuracy: 0.6000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1_score: 0.5657
# Epoch 8/100
# 10/10 [==============================] - 6s 571ms/step - loss: 0.1093 - accuracy: 0.9530 - precision: 0.9649 - recall: 0.9467 - f1_score: 0.9567 - val_loss: 3.2742 - val_accuracy: 0.5000 - val_precision: 0.5063 - val_recall: 0.5000 - val_f1_score: 0.5170
# Epoch 9/100
# 10/10 [==============================] - 6s 633ms/step - loss: 0.1797 - accuracy: 0.9436 - precision: 0.9551 - recall: 0.9342 - f1_score: 0.9490 - val_loss: 3.7792 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5236
# Epoch 10/100
# 10/10 [==============================] - 6s 567ms/step - loss: 0.1240 - accuracy: 0.9592 - precision: 0.9623 - recall: 0.9592 - f1_score: 0.9590 - val_loss: 2.6939 - val_accuracy: 0.5750 - val_precision: 0.5897 - val_recall: 0.5750 - val_f1_score: 0.5541
# Epoch 11/100
# 10/10 [==============================] - 5s 531ms/step - loss: 0.1236 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - f1_score: 0.9681 - val_loss: 2.3856 - val_accuracy: 0.6125 - val_precision: 0.6203 - val_recall: 0.6125 - val_f1_score: 0.5766
# Epoch 12/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.1328 - accuracy: 0.9655 - precision: 0.9654 - recall: 0.9624 - f1_score: 0.9575 - val_loss: 1.8984 - val_accuracy: 0.6750 - val_precision: 0.7013 - val_recall: 0.6750 - val_f1_score: 0.6436
# Epoch 13/100
# 10/10 [==============================] - 6s 571ms/step - loss: 0.1371 - accuracy: 0.9592 - precision: 0.9652 - recall: 0.9561 - f1_score: 0.9580 - val_loss: 1.9424 - val_accuracy: 0.7125 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.6848
# Epoch 14/100
# 10/10 [==============================] - 6s 576ms/step - loss: 0.1281 - accuracy: 0.9530 - precision: 0.9586 - recall: 0.9436 - f1_score: 0.9582 - val_loss: 1.2433 - val_accuracy: 0.7750 - val_precision: 0.7722 - val_recall: 0.7625 - val_f1_score: 0.7400
# Epoch 15/100
# 10/10 [==============================] - 6s 612ms/step - loss: 0.0905 - accuracy: 0.9718 - precision: 0.9716 - recall: 0.9655 - f1_score: 0.9734 - val_loss: 1.7508 - val_accuracy: 0.7250 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.7054
# Epoch 16/100
# 10/10 [==============================] - 5s 482ms/step - loss: 0.1062 - accuracy: 0.9655 - precision: 0.9684 - recall: 0.9592 - f1_score: 0.9698 - val_loss: 2.3653 - val_accuracy: 0.6750 - val_precision: 0.6835 - val_recall: 0.6750 - val_f1_score: 0.6633
# Epoch 17/100
# 10/10 [==============================] - 5s 517ms/step - loss: 0.0694 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - f1_score: 0.9707 - val_loss: 1.9815 - val_accuracy: 0.7125 - val_precision: 0.7125 - val_recall: 0.7125 - val_f1_score: 0.7381
# Epoch 18/100
# 10/10 [==============================] - 5s 560ms/step - loss: 0.0751 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9754 - val_loss: 2.6127 - val_accuracy: 0.6625 - val_precision: 0.6667 - val_recall: 0.6500 - val_f1_score: 0.6847
# Epoch 19/100
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0657 - accuracy: 0.9781 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9811 - val_loss: 3.0123 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.6554
# Epoch 20/100
# 10/10 [==============================] - 5s 542ms/step - loss: 0.1217 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - f1_score: 0.9717 - val_loss: 2.7028 - val_accuracy: 0.7500 - val_precision: 0.7468 - val_recall: 0.7375 - val_f1_score: 0.7287
# Epoch 21/100
# 10/10 [==============================] - 6s 621ms/step - loss: 0.0909 - accuracy: 0.9749 - precision: 0.9810 - recall: 0.9718 - f1_score: 0.9775 - val_loss: 3.2877 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_f1_score: 0.7814
# Epoch 22/100
# 10/10 [==============================] - 6s 660ms/step - loss: 0.1081 - accuracy: 0.9749 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9739 - val_loss: 2.4471 - val_accuracy: 0.8125 - val_precision: 0.8228 - val_recall: 0.8125 - val_f1_score: 0.8130
# Epoch 23/100
# 10/10 [==============================] - 6s 608ms/step - loss: 0.0833 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9789 - val_loss: 1.6123 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_f1_score: 0.7940
# Epoch 24/100
# 10/10 [==============================] - 6s 642ms/step - loss: 0.1144 - accuracy: 0.9624 - precision: 0.9684 - recall: 0.9592 - f1_score: 0.9647 - val_loss: 1.0465 - val_accuracy: 0.7750 - val_precision: 0.7750 - val_recall: 0.7750 - val_f1_score: 0.7857
# Epoch 25/100
# 10/10 [==============================] - 6s 554ms/step - loss: 0.0635 - accuracy: 0.9843 - precision: 0.9842 - recall: 0.9781 - f1_score: 0.9866 - val_loss: 1.4806 - val_accuracy: 0.7250 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7294
# Epoch 26/100
# 10/10 [==============================] - 6s 617ms/step - loss: 0.0701 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - f1_score: 0.9809 - val_loss: 1.6632 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1_score: 0.7756
# Epoch 27/100
# 10/10 [==============================] - 6s 579ms/step - loss: 0.1121 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9737 - val_loss: 1.2001 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_f1_score: 0.8290
# Epoch 28/100
# 10/10 [==============================] - 5s 530ms/step - loss: 0.0639 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9741 - val_loss: 1.5408 - val_accuracy: 0.7500 - val_precision: 0.7564 - val_recall: 0.7375 - val_f1_score: 0.7612
# Epoch 29/100
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0986 - accuracy: 0.9718 - precision: 0.9748 - recall: 0.9687 - f1_score: 0.9735 - val_loss: 1.5271 - val_accuracy: 0.6875 - val_precision: 0.6923 - val_recall: 0.6750 - val_f1_score: 0.6621
# Epoch 30/100
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0962 - accuracy: 0.9592 - precision: 0.9621 - recall: 0.9561 - f1_score: 0.9627 - val_loss: 2.4565 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_f1_score: 0.6889
# Epoch 31/100
# 10/10 [==============================] - 6s 642ms/step - loss: 0.0580 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9875 - f1_score: 0.9908 - val_loss: 3.2568 - val_accuracy: 0.6375 - val_precision: 0.6329 - val_recall: 0.6250 - val_f1_score: 0.6115
# Epoch 32/100
# 10/10 [==============================] - 6s 583ms/step - loss: 0.0912 - accuracy: 0.9655 - precision: 0.9716 - recall: 0.9655 - f1_score: 0.9658 - val_loss: 4.5939 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5196
# Epoch 33/100
# 10/10 [==============================] - 5s 504ms/step - loss: 0.0970 - accuracy: 0.9655 - precision: 0.9686 - recall: 0.9655 - f1_score: 0.9667 - val_loss: 4.2490 - val_accuracy: 0.5875 - val_precision: 0.5949 - val_recall: 0.5875 - val_f1_score: 0.5463
# Epoch 34/100
# 10/10 [==============================] - 5s 521ms/step - loss: 0.0571 - accuracy: 0.9781 - precision: 0.9842 - recall: 0.9781 - f1_score: 0.9761 - val_loss: 4.8198 - val_accuracy: 0.5500 - val_precision: 0.5570 - val_recall: 0.5500 - val_f1_score: 0.4990
# Epoch 35/100
# 10/10 [==============================] - 5s 548ms/step - loss: 0.1032 - accuracy: 0.9592 - precision: 0.9623 - recall: 0.9592 - f1_score: 0.9592 - val_loss: 4.3679 - val_accuracy: 0.5375 - val_precision: 0.5385 - val_recall: 0.5250 - val_f1_score: 0.4755
# Epoch 36/100
# 10/10 [==============================] - 6s 570ms/step - loss: 0.0562 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9812 - f1_score: 0.9848 - val_loss: 4.1137 - val_accuracy: 0.5625 - val_precision: 0.5696 - val_recall: 0.5625 - val_f1_score: 0.5149
# Epoch 37/100
# 10/10 [==============================] - 7s 685ms/step - loss: 0.0621 - accuracy: 0.9781 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9792 - val_loss: 3.5831 - val_accuracy: 0.6125 - val_precision: 0.6125 - val_recall: 0.6125 - val_f1_score: 0.5771
# Epoch 38/100
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0493 - accuracy: 0.9875 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9888 - val_loss: 3.3144 - val_accuracy: 0.6750 - val_precision: 0.6750 - val_recall: 0.6750 - val_f1_score: 0.6511
# Epoch 39/100
# 10/10 [==============================] - 6s 587ms/step - loss: 0.0713 - accuracy: 0.9749 - precision: 0.9748 - recall: 0.9718 - f1_score: 0.9737 - val_loss: 4.2788 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.6016
# Epoch 40/100
# 10/10 [==============================] - 5s 489ms/step - loss: 0.0585 - accuracy: 0.9781 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9798 - val_loss: 3.8807 - val_accuracy: 0.6375 - val_precision: 0.6538 - val_recall: 0.6375 - val_f1_score: 0.6165
# Epoch 41/100
# 10/10 [==============================] - 5s 506ms/step - loss: 0.0583 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9856 - val_loss: 2.4471 - val_accuracy: 0.6750 - val_precision: 0.6750 - val_recall: 0.6750 - val_f1_score: 0.6922
# Epoch 42/100
# 10/10 [==============================] - 6s 556ms/step - loss: 0.0575 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9854 - val_loss: 3.8675 - val_accuracy: 0.6500 - val_precision: 0.6500 - val_recall: 0.6500 - val_f1_score: 0.6241
# Epoch 43/100
# 10/10 [==============================] - 6s 521ms/step - loss: 0.0824 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9804 - val_loss: 3.0361 - val_accuracy: 0.6625 - val_precision: 0.6709 - val_recall: 0.6625 - val_f1_score: 0.6503
# Epoch 44/100
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0236 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9914 - val_loss: 2.1865 - val_accuracy: 0.7625 - val_precision: 0.7625 - val_recall: 0.7625 - val_f1_score: 0.7740
# Epoch 45/100
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0323 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9944 - val_loss: 2.7284 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1_score: 0.7657
# Epoch 46/100
# 10/10 [==============================] - 6s 626ms/step - loss: 0.0727 - accuracy: 0.9624 - precision: 0.9715 - recall: 0.9624 - f1_score: 0.9668 - val_loss: 1.7692 - val_accuracy: 0.7750 - val_precision: 0.7722 - val_recall: 0.7625 - val_f1_score: 0.7848
# Epoch 47/100
# 10/10 [==============================] - 6s 597ms/step - loss: 0.0280 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9883 - val_loss: 1.5999 - val_accuracy: 0.7500 - val_precision: 0.7692 - val_recall: 0.7500 - val_f1_score: 0.7371
# Epoch 48/100
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0337 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9907 - val_loss: 3.1719 - val_accuracy: 0.7375 - val_precision: 0.7436 - val_recall: 0.7250 - val_f1_score: 0.7523
# Epoch 49/100
# 10/10 [==============================] - 6s 670ms/step - loss: 0.0635 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - f1_score: 0.9832 - val_loss: 2.5320 - val_accuracy: 0.6625 - val_precision: 0.6625 - val_recall: 0.6625 - val_f1_score: 0.6568
# Epoch 50/100
# 10/10 [==============================] - 6s 558ms/step - loss: 0.0478 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9859 - val_loss: 1.9353 - val_accuracy: 0.6500 - val_precision: 0.6582 - val_recall: 0.6500 - val_f1_score: 0.6422
# Epoch 51/100
# 10/10 [==============================] - 5s 561ms/step - loss: 0.0559 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9858 - val_loss: 1.7676 - val_accuracy: 0.7125 - val_precision: 0.7125 - val_recall: 0.7125 - val_f1_score: 0.7286
# Epoch 52/100
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0406 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9843 - f1_score: 0.9880 - val_loss: 2.2339 - val_accuracy: 0.7000 - val_precision: 0.7179 - val_recall: 0.7000 - val_f1_score: 0.7028
# Epoch 53/100
# 10/10 [==============================] - 5s 535ms/step - loss: 0.0854 - accuracy: 0.9812 - precision: 0.9811 - recall: 0.9781 - f1_score: 0.9832 - val_loss: 1.4379 - val_accuracy: 0.7375 - val_precision: 0.7375 - val_recall: 0.7375 - val_f1_score: 0.7481
# Epoch 54/100
# 10/10 [==============================] - 5s 478ms/step - loss: 0.0709 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9857 - val_loss: 2.3730 - val_accuracy: 0.7125 - val_precision: 0.7179 - val_recall: 0.7000 - val_f1_score: 0.7239
# Epoch 55/100
# 10/10 [==============================] - 5s 504ms/step - loss: 0.0895 - accuracy: 0.9687 - precision: 0.9687 - recall: 0.9687 - f1_score: 0.9651 - val_loss: 2.1304 - val_accuracy: 0.7125 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.7211
# Epoch 56/100
# 10/10 [==============================] - 6s 618ms/step - loss: 0.0672 - accuracy: 0.9781 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9777 - val_loss: 2.5723 - val_accuracy: 0.6625 - val_precision: 0.6625 - val_recall: 0.6625 - val_f1_score: 0.6997
# Epoch 57/100
# 10/10 [==============================] - 5s 565ms/step - loss: 0.0539 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9812 - f1_score: 0.9862 - val_loss: 3.0796 - val_accuracy: 0.6625 - val_precision: 0.6625 - val_recall: 0.6625 - val_f1_score: 0.6947
# Epoch 58/100
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0420 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9893 - val_loss: 2.7388 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.7158
# Epoch 59/100
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0516 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9850 - val_loss: 2.5526 - val_accuracy: 0.7000 - val_precision: 0.7000 - val_recall: 0.7000 - val_f1_score: 0.7334
# Epoch 60/100
# 10/10 [==============================] - 5s 507ms/step - loss: 0.0498 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9856 - val_loss: 3.2789 - val_accuracy: 0.6625 - val_precision: 0.6667 - val_recall: 0.6500 - val_f1_score: 0.6207
# Epoch 61/100
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0389 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9888 - val_loss: 3.7454 - val_accuracy: 0.6125 - val_precision: 0.6125 - val_recall: 0.6125 - val_f1_score: 0.5743
# Epoch 62/100
# 10/10 [==============================] - 6s 627ms/step - loss: 0.0519 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9848 - val_loss: 3.4136 - val_accuracy: 0.6250 - val_precision: 0.6329 - val_recall: 0.6250 - val_f1_score: 0.5913
# Epoch 63/100
# 10/10 [==============================] - 5s 475ms/step - loss: 0.0456 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9883 - val_loss: 2.1796 - val_accuracy: 0.7125 - val_precision: 0.7215 - val_recall: 0.7125 - val_f1_score: 0.6956
# Epoch 64/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0566 - accuracy: 0.9843 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9858 - val_loss: 2.1382 - val_accuracy: 0.7250 - val_precision: 0.7436 - val_recall: 0.7250 - val_f1_score: 0.7200
# Epoch 65/100
# 10/10 [==============================] - 5s 538ms/step - loss: 0.0592 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9853 - val_loss: 2.5625 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.7009
# Epoch 66/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0518 - accuracy: 0.9875 - precision: 0.9874 - recall: 0.9843 - f1_score: 0.9878 - val_loss: 1.8624 - val_accuracy: 0.7125 - val_precision: 0.7125 - val_recall: 0.7125 - val_f1_score: 0.7305
# Epoch 67/100
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0511 - accuracy: 0.9843 - precision: 0.9905 - recall: 0.9812 - f1_score: 0.9854 - val_loss: 2.0563 - val_accuracy: 0.7375 - val_precision: 0.7436 - val_recall: 0.7250 - val_f1_score: 0.7536
# Epoch 68/100
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0180 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 2.0206 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_f1_score: 0.7573
# Epoch 69/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0223 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9907 - val_loss: 1.9169 - val_accuracy: 0.7000 - val_precision: 0.7089 - val_recall: 0.7000 - val_f1_score: 0.7019
# Epoch 70/100
# 10/10 [==============================] - 5s 549ms/step - loss: 0.0125 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 1.9640 - val_accuracy: 0.6875 - val_precision: 0.6962 - val_recall: 0.6875 - val_f1_score: 0.6775
# Epoch 71/100
# 10/10 [==============================] - 6s 588ms/step - loss: 0.0186 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9975 - val_loss: 2.0534 - val_accuracy: 0.7250 - val_precision: 0.7342 - val_recall: 0.7250 - val_f1_score: 0.7137
# Epoch 72/100
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0142 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9943 - val_loss: 2.2432 - val_accuracy: 0.7250 - val_precision: 0.7368 - val_recall: 0.7000 - val_f1_score: 0.7187
# Epoch 73/100
# 10/10 [==============================] - 5s 548ms/step - loss: 0.0356 - accuracy: 0.9812 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9837 - val_loss: 1.7107 - val_accuracy: 0.7250 - val_precision: 0.7250 - val_recall: 0.7250 - val_f1_score: 0.7257
# Epoch 74/100
# 10/10 [==============================] - 5s 467ms/step - loss: 0.0140 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9974 - val_loss: 1.8216 - val_accuracy: 0.7625 - val_precision: 0.7625 - val_recall: 0.7625 - val_f1_score: 0.7527
# Epoch 75/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0615 - accuracy: 0.9749 - precision: 0.9780 - recall: 0.9749 - f1_score: 0.9786 - val_loss: 2.0124 - val_accuracy: 0.7500 - val_precision: 0.7468 - val_recall: 0.7375 - val_f1_score: 0.7350
# Epoch 76/100
# 10/10 [==============================] - 5s 549ms/step - loss: 0.0206 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9925 - val_loss: 2.7965 - val_accuracy: 0.6625 - val_precision: 0.6625 - val_recall: 0.6625 - val_f1_score: 0.6149
# Epoch 77/100
# 10/10 [==============================] - 5s 545ms/step - loss: 0.0204 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9975 - val_loss: 3.0514 - val_accuracy: 0.6375 - val_precision: 0.6375 - val_recall: 0.6375 - val_f1_score: 0.5881
# Epoch 78/100
# 10/10 [==============================] - 5s 513ms/step - loss: 0.0206 - accuracy: 0.9937 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9939 - val_loss: 3.0661 - val_accuracy: 0.6125 - val_precision: 0.6125 - val_recall: 0.6125 - val_f1_score: 0.5675
# Epoch 79/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.0142 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9939 - val_loss: 3.1455 - val_accuracy: 0.6625 - val_precision: 0.6667 - val_recall: 0.6500 - val_f1_score: 0.6307
# Epoch 80/100
# ...
# Epoch 42/100
# 10/10 [==============================] - 5s 475ms/step - loss: 0.0199 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9916 - val_loss: 0.5528 - val_accuracy: 0.9114 - val_precision: 0.9103 - val_recall: 0.8987 - val_f1_score: 0.9171
# Epoch 43/100
# 10/10 [==============================] - 5s 469ms/step - loss: 0.0130 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9945 - val_loss: 0.5961 - val_accuracy: 0.8987 - val_precision: 0.8974 - val_recall: 0.8861 - val_f1_score: 0.9058
# Epoch 44/100
# 10/10 [==============================] - 4s 457ms/step - loss: 0.0702 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9922 - val_loss: 1.3949 - val_accuracy: 0.8101 - val_precision: 0.8077 - val_recall: 0.7975 - val_f1_score: 0.8468
# Epoch 45/100
# 10/10 [==============================] - 5s 451ms/step - loss: 0.0286 - accuracy: 0.9844 - precision: 0.9844 - recall: 0.9844 - f1_score: 0.9873 - val_loss: 1.8594 - val_accuracy: 0.7848 - val_precision: 0.7821 - val_recall: 0.7722 - val_f1_score: 0.8318
# Epoch 46/100
# 10/10 [==============================] - 5s 457ms/step - loss: 0.0054 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.8520 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_f1_score: 0.8629
# Epoch 47/100
# 10/10 [==============================] - 5s 479ms/step - loss: 0.0185 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9901 - val_loss: 0.6992 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_f1_score: 0.8675
# Epoch 48/100
# 10/10 [==============================] - 4s 432ms/step - loss: 0.0096 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9951 - val_loss: 1.0981 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_f1_score: 0.8571
# Epoch 49/100
# 10/10 [==============================] - 4s 424ms/step - loss: 0.0357 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9916 - val_loss: 0.3193 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9322
# Epoch 50/100
# 10/10 [==============================] - 5s 472ms/step - loss: 0.0303 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9919 - val_loss: 0.2105 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.9175
# Epoch 51/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.0137 - accuracy: 0.9937 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9945 - val_loss: 0.2428 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.9203
# Epoch 52/100
# 10/10 [==============================] - 5s 468ms/step - loss: 0.0155 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9943 - val_loss: 0.2152 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_f1_score: 0.8958
# Epoch 53/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0158 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9949 - val_loss: 0.1659 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9436
# Epoch 54/100
# 10/10 [==============================] - 5s 451ms/step - loss: 0.0078 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9976 - val_loss: 0.1581 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9436
# Epoch 55/100
# 10/10 [==============================] - 5s 483ms/step - loss: 0.0039 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9435
# Epoch 56/100
# 10/10 [==============================] - 4s 456ms/step - loss: 0.0273 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9912 - val_loss: 0.3015 - val_accuracy: 0.8861 - val_precision: 0.8846 - val_recall: 0.8734 - val_f1_score: 0.8924
# Epoch 57/100
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0119 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9947 - val_loss: 0.4065 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_f1_score: 0.8676
# Epoch 58/100
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0173 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9971 - val_loss: 0.1843 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9529
# Epoch 59/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0093 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9971 - val_loss: 0.2164 - val_accuracy: 0.9494 - val_precision: 0.9487 - val_recall: 0.9367 - val_f1_score: 0.9557
# Epoch 60/100
# 10/10 [==============================] - 5s 481ms/step - loss: 0.0053 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9620 - val_precision: 0.9615 - val_recall: 0.9494 - val_f1_score: 0.9686
# Epoch 61/100
# 10/10 [==============================] - 5s 489ms/step - loss: 0.0069 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9975 - val_loss: 0.2176 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9557
# Epoch 62/100
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0056 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.1987 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9557
# Epoch 63/100
# 10/10 [==============================] - 5s 459ms/step - loss: 0.0049 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9558
# Epoch 64/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0019 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9558
# Epoch 65/100
# 10/10 [==============================] - 4s 446ms/step - loss: 0.0152 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9940 - val_loss: 0.4995 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.9271
# Epoch 66/100
# 10/10 [==============================] - 5s 457ms/step - loss: 0.0368 - accuracy: 0.9906 - precision: 0.9937 - recall: 0.9906 - f1_score: 0.9911 - val_loss: 0.1373 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9524
# Epoch 67/100
# 10/10 [==============================] - 4s 451ms/step - loss: 0.0119 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9969 - val_loss: 0.1500 - val_accuracy: 0.9873 - val_precision: 0.9873 - val_recall: 0.9873 - val_f1_score: 0.9854
# Epoch 68/100
# 10/10 [==============================] - 5s 477ms/step - loss: 0.0130 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9942 - val_loss: 0.1168 - val_accuracy: 0.9620 - val_precision: 0.9620 - val_recall: 0.9620 - val_f1_score: 0.9565
# Epoch 69/100
# 10/10 [==============================] - 5s 489ms/step - loss: 0.0017 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9199
# Epoch 70/100
# 10/10 [==============================] - 5s 460ms/step - loss: 0.0055 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9969 - val_loss: 0.1909 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9336
# Epoch 71/100
# 10/10 [==============================] - 4s 405ms/step - loss: 0.0052 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9186
# Epoch 72/100
# 10/10 [==============================] - 4s 451ms/step - loss: 0.0039 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9336
# Epoch 73/100
# 10/10 [==============================] - 4s 442ms/step - loss: 0.0039 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9276
# Epoch 74/100
# 10/10 [==============================] - 5s 465ms/step - loss: 0.0018 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9494 - val_precision: 0.9494 - val_recall: 0.9494 - val_f1_score: 0.9517
# Epoch 75/100
# 10/10 [==============================] - 5s 473ms/step - loss: 0.0057 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9976 - val_loss: 0.1883 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.8939
# Epoch 76/100
# 10/10 [==============================] - 4s 422ms/step - loss: 0.0075 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9944 - val_loss: 0.5941 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.9070
# Epoch 77/100
# 10/10 [==============================] - 4s 450ms/step - loss: 0.0371 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9805 - val_loss: 0.5893 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_f1_score: 0.9149
# Epoch 78/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0077 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9935 - val_loss: 0.5955 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.8972
# Epoch 79/100
# 10/10 [==============================] - 4s 438ms/step - loss: 0.0183 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9938 - val_loss: 0.6030 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.8829
# Epoch 80/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0027 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6058 - val_accuracy: 0.8987 - val_precision: 0.9103 - val_recall: 0.8987 - val_f1_score: 0.8895
# Epoch 81/100
# 10/10 [==============================] - 4s 426ms/step - loss: 0.0540 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9896 - val_loss: 0.8010 - val_accuracy: 0.8228 - val_precision: 0.8333 - val_recall: 0.8228 - val_f1_score: 0.8368
# Epoch 82/100
# 10/10 [==============================] - 4s 425ms/step - loss: 0.0080 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9976 - val_loss: 0.5740 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.8769
# Epoch 83/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0473 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9882 - val_loss: 0.5028 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_f1_score: 0.9003
# Epoch 84/100
# 10/10 [==============================] - 4s 444ms/step - loss: 0.0122 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9937 - f1_score: 0.9970 - val_loss: 0.7251 - val_accuracy: 0.8734 - val_precision: 0.8846 - val_recall: 0.8734 - val_f1_score: 0.8745
# Epoch 85/100
# 10/10 [==============================] - 5s 452ms/step - loss: 0.0125 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9941 - val_loss: 0.8192 - val_accuracy: 0.8987 - val_precision: 0.8961 - val_recall: 0.8734 - val_f1_score: 0.9044
# Epoch 86/100
# 10/10 [==============================] - 5s 457ms/step - loss: 0.0222 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9880 - val_loss: 0.6628 - val_accuracy: 0.8861 - val_precision: 0.8846 - val_recall: 0.8734 - val_f1_score: 0.8871
# Epoch 87/100
# 10/10 [==============================] - 5s 479ms/step - loss: 0.0061 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9970 - val_loss: 0.4899 - val_accuracy: 0.8861 - val_precision: 0.8974 - val_recall: 0.8861 - val_f1_score: 0.8739
# Epoch 88/100
# 10/10 [==============================] - 4s 461ms/step - loss: 0.0170 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9912 - val_loss: 0.3898 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9207
# Epoch 89/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0093 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9976 - val_loss: 0.2984 - val_accuracy: 0.9241 - val_precision: 0.9359 - val_recall: 0.9241 - val_f1_score: 0.9282
# Epoch 90/100
# 10/10 [==============================] - 5s 479ms/step - loss: 0.0085 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9976 - val_loss: 0.3222 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_f1_score: 0.9379
# Epoch 91/100
# 10/10 [==============================] - 4s 421ms/step - loss: 0.0214 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9937 - f1_score: 0.9947 - val_loss: 0.3448 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9319
# Epoch 92/100
# 10/10 [==============================] - 4s 442ms/step - loss: 0.0069 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_f1_score: 0.9339
# Epoch 93/100
# 10/10 [==============================] - 5s 476ms/step - loss: 0.0945 - accuracy: 0.9844 - precision: 0.9843 - recall: 0.9812 - f1_score: 0.9822 - val_loss: 0.7028 - val_accuracy: 0.8354 - val_precision: 0.8312 - val_recall: 0.8101 - val_f1_score: 0.8631
# Epoch 94/100
# 10/10 [==============================] - 4s 427ms/step - loss: 0.0545 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9920 - val_loss: 1.3189 - val_accuracy: 0.8101 - val_precision: 0.8101 - val_recall: 0.8101 - val_f1_score: 0.8373
# Epoch 95/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0398 - accuracy: 0.9875 - precision: 0.9906 - recall: 0.9875 - f1_score: 0.9877 - val_loss: 0.9243 - val_accuracy: 0.7975 - val_precision: 0.7975 - val_recall: 0.7975 - val_f1_score: 0.8346
# Epoch 96/100
# 10/10 [==============================] - 4s 451ms/step - loss: 0.0169 - accuracy: 0.9969 - precision: 0.9969 - recall: 0.9969 - f1_score: 0.9971 - val_loss: 0.6074 - val_accuracy: 0.8608 - val_precision: 0.8831 - val_recall: 0.8608 - val_f1_score: 0.8714
# Epoch 97/100
# 10/10 [==============================] - 4s 442ms/step - loss: 0.0202 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - f1_score: 0.9914 - val_loss: 1.1920 - val_accuracy: 0.7848 - val_precision: 0.7848 - val_recall: 0.7848 - val_f1_score: 0.8086
# Epoch 98/100
# 10/10 [==============================] - 5s 525ms/step - loss: 0.0224 - accuracy: 0.9937 - precision: 0.9937 - recall: 0.9875 - f1_score: 0.9950 - val_loss: 0.9265 - val_accuracy: 0.7975 - val_precision: 0.7975 - val_recall: 0.7975 - val_f1_score: 0.8063
# Epoch 99/100
# 10/10 [==============================] - 4s 435ms/step - loss: 0.0053 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.7428 - val_accuracy: 0.8228 - val_precision: 0.8421 - val_recall: 0.8101 - val_f1_score: 0.8204
# Epoch 100/100
# 10/10 [==============================] - 5s 464ms/step - loss: 0.0338 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - f1_score: 0.9892 - val_loss: 0.6448 - val_accuracy: 0.7848 - val_precision: 0.8052 - val_recall: 0.7848 - val_f1_score: 0.7870

# %%
combined_history = {}
for metric in history_list[0].keys():
    combined_history[metric] = []
    for hist in history_list:
        combined_history[metric].extend(hist[metric])

# Plot the combined history
plt.plot(combined_history['loss'])
plt.plot(combined_history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(combined_history['accuracy'])
plt.plot(combined_history['val_accuracy'])
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(combined_history['precision'])
plt.plot(combined_history['val_precision'])
plt.grid()
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
plt.plot(combined_history['recall'])
plt.plot(combined_history['val_recall'])
plt.grid()
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
test_data_dir = '/content/drive/MyDrive/ testdata/testdata/testdata'
test_data_dir = pathlib.Path(test_data_dir)
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
)

# convert it to one hot encoded
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, total_classes)))

test_images = []
test_labels = []
for images, labels in test_dataset:
    test_images.append(images.numpy())
    test_labels.append(labels.numpy())

test_images = np.concatenate(test_images)
test_labels = np.concatenate(test_labels)
# Out:
# Found 81 files belonging to 6 classes.

# %%
predictions = model.predict(test_images)
# Out:
# 3/3 [==============================] - 4s 674ms/step

# %%
test_labels = np.argmax(test_labels, axis=-1)
predictions = np.argmax(predictions, axis=-1)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(test_labels, predictions)
precision = precision_score(test_labels, predictions, average='macro')
recall = recall_score(test_labels, predictions, average='macro')
f1 = f1_score(test_labels, predictions, average='macro')

print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
print(f"Test Recall: {recall}")
print(f"Test F1-Score: {f1}")
# Out:
# Test Accuracy: 0.8765432098765432
# Test Precision: 0.8988095238095237
# Test Recall: 0.906926406926407
# Test F1-Score: 0.885865024881043

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(test_labels, predictions)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, predictions, target_names=class_names))
# Out:
#                           precision    recall  f1-score   support
#
# Hypertensive retinopathy       1.00      1.00      1.00        10
#            Mild NPDR (1)       0.64      1.00      0.78         9
#        Moderate NPDR (2)       1.00      0.71      0.83        14
#                  NO_DR 0       0.75      1.00      0.86        15
#       Proliferative DR 4       1.00      1.00      1.00        11
#            Severe NPDR 3       1.00      0.73      0.84        22
#
#                 accuracy                           0.88        81
#                macro avg       0.90      0.91      0.89        81
#             weighted avg       0.91      0.88      0.88        81
